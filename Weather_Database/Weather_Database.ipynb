# %%
import numpy as np 
from citipy import citipy
import requests
import pandas as pd 
from datetime import datetime

from config import weather_api_key
from config import g_key

# %%
# Generate 2,000 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# Get the nearest city using the citipy module.
cities = list()
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['khatanga', 'pisco', 'bluff', 'codrington', 'hithadhoo', 'auki', 'busselton', 'buenos aires', 'mataura', 'flin flon'] Generate 754

# %%
# Perform an API call with the OpenWeatherMap.

# initial counters for log and sets
record_count = 1 
set_count = 1

city_data = []
basic_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")

# use enumerate() method to loop index and item simutanously 
for i, item in enumerate(cities):
    if (i % 50 == 0 and i != 0) :
        record_count = 1  
        set_count +=1 
        
    # build URL for API call
    url = basic_url + '&q=' + item
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {item}')
    # increment record count
    record_count +=1

    try:
        # Parse the JSON and retrieve data.
        js = requests.get(url).json()

        # Parse out the needed data.
        city_name = item
        city_country = js['sys']['country']
        city_UTCdate = js['dt']
        city_date = datetime.utcfromtimestamp(city_UTCdate).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = js['coord']['lat']
        city_lon = js['coord']['lon']
        city_max_temp = js['main']['temp_max']
        city_humidity = js['main']['humidity']
        city_cload = js['clouds']['all']
        city_wind_speed = js['wind']['speed']
        city_weather_description = js['weather'][0]['description']   

        # append as a list of dictionaries
        city_data.append({'City':city_name, 'Country':city_country, 'Date':city_date, 
                        'Lat':city_lat, 'Lng': city_lon,'Max Temp':city_max_temp,
                        'Humidity':city_humidity,'Cloudiness': city_cload,'Wind Speed':city_wind_speed,
                        'Current Description':city_weather_description})
    except:
        print("City not found. Skipping...")
        pass
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khatanga
# Processing Record 2 of Set 1 | pisco
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | codrington
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | auki
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | buenos aires
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | flin flon
# Processing Record 11 of Set 1 | quatre cocos
# Processing Record 12 of Set 1 | hokitika
# Processing Record 13 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 1 | narsaq
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | lashio
# Processing Record 17 of Set 1 | porto novo
# Processing Record 18 of Set 1 | paamiut
# Processing Record 19 of Set 1 | lorengau
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | ixtapa
# Processing Record 22 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 1 | kalga
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | ilulissat
# Processing Record 27 of Set 1 | omboue
# Processing Record 28 of Set 1 | kahului
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | cairns
# Processing Record 33 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 34 of Set 1 | cidreira
# Processing Record 35 of Set 1 | leningradskiy
# Processing Record 36 of Set 1 | ribeira grande
# Processing Record 37 of Set 1 | sao miguel do araguaia
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | san carlos de bariloche
# Processing Record 40 of Set 1 | balykshi
# Processing Record 41 of Set 1 | lamu
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | norman wells
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | trincomalee
# Processing Record 47 of Set 1 | champerico
# Processing Record 48 of Set 1 | kamenka
# Processing Record 49 of Set 1 | havoysund
# Processing Record 50 of Set 1 | alma
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | pangnirtung
# Processing Record 3 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | klaksvik
# Processing Record 6 of Set 2 | ancud
# Processing Record 7 of Set 2 | udachnyy
# Processing Record 8 of Set 2 | dunedin
# Processing Record 9 of Set 2 | sur
# Processing Record 10 of Set 2 | kavieng
# Processing Record 11 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 2 | sao filipe
# Processing Record 13 of Set 2 | chuy
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 2 | souillac
# Processing Record 20 of Set 2 | dickinson
# Processing Record 21 of Set 2 | piacabucu
# Processing Record 22 of Set 2 | saint george
# Processing Record 23 of Set 2 | fortuna
# Processing Record 24 of Set 2 | nemuro
# Processing Record 25 of Set 2 | sitka
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 2 | hobart
# Processing Record 28 of Set 2 | constitucion
# Processing Record 29 of Set 2 | airai
# Processing Record 30 of Set 2 | dingle
# Processing Record 31 of Set 2 | gwadar
# Processing Record 32 of Set 2 | port elizabeth
# Processing Record 33 of Set 2 | taoudenni
# Processing Record 34 of Set 2 | vryburg
# Processing Record 35 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 2 | iqaluit
# Processing Record 37 of Set 2 | villeneuve-sur-lot
# Processing Record 38 of Set 2 | atar
# Processing Record 39 of Set 2 | hasaki
# Processing Record 40 of Set 2 | yerbogachen
# Processing Record 41 of Set 2 | rio grande
# Processing Record 42 of Set 2 | deputatskiy
# Processing Record 43 of Set 2 | saumur
# Processing Record 44 of Set 2 | saint-philippe
# Processing Record 45 of Set 2 | aloleng
# Processing Record 46 of Set 2 | sorland
# Processing Record 47 of Set 2 | kapaa
# Processing Record 48 of Set 2 | yulara
# Processing Record 49 of Set 2 | lac du bonnet
# Processing Record 50 of Set 2 | vardo
# Processing Record 1 of Set 3 | karratha
# Processing Record 2 of Set 3 | lakes entrance
# Processing Record 3 of Set 3 | albany
# Processing Record 4 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 3 | lithakia
# Processing Record 6 of Set 3 | muli
# Processing Record 7 of Set 3 | marystown
# Processing Record 8 of Set 3 | mbanza-ngungu
# Processing Record 9 of Set 3 | esil
# Processing Record 10 of Set 3 | kurilsk
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 3 | north platte
# Processing Record 14 of Set 3 | staicele
# Processing Record 15 of Set 3 | oranjestad
# Processing Record 16 of Set 3 | skjervoy
# Processing Record 17 of Set 3 | cabo san lucas
# Processing Record 18 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 3 | aklavik
# Processing Record 20 of Set 3 | ipixuna
# Processing Record 21 of Set 3 | brezovo
# Processing Record 22 of Set 3 | saskylakh
# Processing Record 23 of Set 3 | virginia beach
# Processing Record 24 of Set 3 | chokurdakh
# Processing Record 25 of Set 3 | mayo
# Processing Record 26 of Set 3 | hilo
# Processing Record 27 of Set 3 | belyye berega
# Processing Record 28 of Set 3 | cururupu
# Processing Record 29 of Set 3 | rehoboth
# Processing Record 30 of Set 3 | nikolskoye
# Processing Record 31 of Set 3 | belle glade
# Processing Record 32 of Set 3 | alofi
# Processing Record 33 of Set 3 | barahona
# Processing Record 34 of Set 3 | upernavik
# Processing Record 35 of Set 3 | mangaratiba
# Processing Record 36 of Set 3 | cherskiy
# Processing Record 37 of Set 3 | bay city
# Processing Record 38 of Set 3 | kalaleh
# Processing Record 39 of Set 3 | torbay
# Processing Record 40 of Set 3 | marsh harbour
# Processing Record 41 of Set 3 | hamadan
# Processing Record 42 of Set 3 | axim
# Processing Record 43 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 3 | luderitz
# Processing Record 45 of Set 3 | cape town
# Processing Record 46 of Set 3 | ostrovnoy
# Processing Record 47 of Set 3 | ahipara
# Processing Record 48 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 3 | mitsamiouli
# Processing Record 50 of Set 3 | aswan
# Processing Record 1 of Set 4 | padang
# Processing Record 2 of Set 4 | rio gallegos
# Processing Record 3 of Set 4 | ust-barguzin
# Processing Record 4 of Set 4 | mackay
# Processing Record 5 of Set 4 | hami
# Processing Record 6 of Set 4 | novikovo
# Processing Record 7 of Set 4 | puerto ayora
# Processing Record 8 of Set 4 | kutno
# Processing Record 9 of Set 4 | geraldton
# Processing Record 10 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 4 | rawson
# Processing Record 12 of Set 4 | port alfred
# Processing Record 13 of Set 4 | nabire
# Processing Record 14 of Set 4 | kaitangata
# Processing Record 15 of Set 4 | kondinskoye
# Processing Record 16 of Set 4 | anadyr
# Processing Record 17 of Set 4 | nalut
# Processing Record 18 of Set 4 | half moon bay
# Processing Record 19 of Set 4 | tuktoyaktuk
# Processing Record 20 of Set 4 | srivardhan
# Processing Record 21 of Set 4 | kodiak
# Processing Record 22 of Set 4 | coahuayana
# Processing Record 23 of Set 4 | celestun
# Processing Record 24 of Set 4 | belen
# Processing Record 25 of Set 4 | barrow
# Processing Record 26 of Set 4 | yellowknife
# Processing Record 27 of Set 4 | avarua
# Processing Record 28 of Set 4 | grindavik
# Processing Record 29 of Set 4 | nome
# Processing Record 30 of Set 4 | emba
# Processing Record 31 of Set 4 | georgetown
# Processing Record 32 of Set 4 | ilhabela
# Processing Record 33 of Set 4 | beloha
# Processing Record 34 of Set 4 | tiksi
# Processing Record 35 of Set 4 | pevek
# Processing Record 36 of Set 4 | sanchi
# Processing Record 37 of Set 4 | fare
# Processing Record 38 of Set 4 | port hardy
# Processing Record 39 of Set 4 | bredasdorp
# Processing Record 40 of Set 4 | bathsheba
# Processing Record 41 of Set 4 | qaanaaq
# Processing Record 42 of Set 4 | faanui
# Processing Record 43 of Set 4 | shingu
# Processing Record 44 of Set 4 | ayagoz
# Processing Record 45 of Set 4 | aktau
# Processing Record 46 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 4 | culebra
# Processing Record 48 of Set 4 | imeni morozova
# Processing Record 49 of Set 4 | manta
# Processing Record 50 of Set 4 | hyeres
# Processing Record 1 of Set 5 | ulagan
# Processing Record 2 of Set 5 | goundam
# Processing Record 3 of Set 5 | hukuntsi
# Processing Record 4 of Set 5 | la rioja
# Processing Record 5 of Set 5 | thompson
# Processing Record 6 of Set 5 | hofn
# Processing Record 7 of Set 5 | byron bay
# Processing Record 8 of Set 5 | clyde river
# Processing Record 9 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 5 | cervo
# Processing Record 11 of Set 5 | pandan
# Processing Record 12 of Set 5 | yerofey pavlovich
# Processing Record 13 of Set 5 | avera
# Processing Record 14 of Set 5 | karpathos
# Processing Record 15 of Set 5 | floro
# Processing Record 16 of Set 5 | kutum
# Processing Record 17 of Set 5 | christchurch
# Processing Record 18 of Set 5 | mubi
# Processing Record 19 of Set 5 | wadi maliz
# Processing Record 20 of Set 5 | thai nguyen
# Processing Record 21 of Set 5 | stege
# Processing Record 22 of Set 5 | totness
# Processing Record 23 of Set 5 | flinders
# Processing Record 24 of Set 5 | saint-denis
# Processing Record 25 of Set 5 | leshukonskoye
# Processing Record 26 of Set 5 | port blair
# Processing Record 27 of Set 5 | port antonio
# Processing Record 28 of Set 5 | vestmannaeyjar
# Processing Record 29 of Set 5 | bosaso
# Processing Record 30 of Set 5 | guerrero negro
# Processing Record 31 of Set 5 | rundu
# Processing Record 32 of Set 5 | mbandaka
# Processing Record 33 of Set 5 | riverton
# Processing Record 34 of Set 5 | genhe
# Processing Record 35 of Set 5 | mount gambier
# Processing Record 36 of Set 5 | qui nhon
# Processing Record 37 of Set 5 | ponta do sol
# Processing Record 38 of Set 5 | saint-francois
# Processing Record 39 of Set 5 | bandarbeyla
# Processing Record 40 of Set 5 | bundaberg
# Processing Record 41 of Set 5 | lebu
# Processing Record 42 of Set 5 | ucluelet
# Processing Record 43 of Set 5 | victoria
# Processing Record 44 of Set 5 | fort nelson
# Processing Record 45 of Set 5 | khairpur
# Processing Record 46 of Set 5 | tarko-sale
# Processing Record 47 of Set 5 | hamilton
# Processing Record 48 of Set 5 | la ronge
# Processing Record 49 of Set 5 | esperance
# Processing Record 50 of Set 5 | kavaratti
# Processing Record 1 of Set 6 | aden
# Processing Record 2 of Set 6 | pangkalanbuun
# Processing Record 3 of Set 6 | myrtle beach
# Processing Record 4 of Set 6 | longyearbyen
# Processing Record 5 of Set 6 | hobyo
# Processing Record 6 of Set 6 | ostersund
# Processing Record 7 of Set 6 | sechenovo
# Processing Record 8 of Set 6 | bilibino
# Processing Record 9 of Set 6 | gorontalo
# Processing Record 10 of Set 6 | forbes
# Processing Record 11 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 12 of Set 6 | muchkapskiy
# Processing Record 13 of Set 6 | kieta
# Processing Record 14 of Set 6 | dengzhou
# Processing Record 15 of Set 6 | chinchani
# Processing Record 16 of Set 6 | ipu
# Processing Record 17 of Set 6 | sabha
# Processing Record 18 of Set 6 | myrtle grove
# Processing Record 19 of Set 6 | sao jose
# Processing Record 20 of Set 6 | sirpur
# Processing Record 21 of Set 6 | jefferson city
# Processing Record 22 of Set 6 | buraydah
# Processing Record 23 of Set 6 | tautira
# Processing Record 24 of Set 6 | hare bay
# Processing Record 25 of Set 6 | pahrump
# Processing Record 26 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 6 | shizukuishi
# Processing Record 28 of Set 6 | karacabey
# Processing Record 29 of Set 6 | ketchikan
# Processing Record 30 of Set 6 | ashland
# Processing Record 31 of Set 6 | gazojak
# Processing Record 32 of Set 6 | ponta delgada
# Processing Record 33 of Set 6 | comodoro rivadavia
# Processing Record 34 of Set 6 | sabang
# Processing Record 35 of Set 6 | puerto colombia
# Processing Record 36 of Set 6 | lingao
# Processing Record 37 of Set 6 | longonjo
# Processing Record 38 of Set 6 | mnogovershinnyy
# Processing Record 39 of Set 6 | oktyabrskiy
# Processing Record 40 of Set 6 | abu samrah
# Processing Record 41 of Set 6 | shahdadkot
# Processing Record 42 of Set 6 | cayenne
# Processing Record 43 of Set 6 | vila franca do campo
# Processing Record 44 of Set 6 | gillette
# Processing Record 45 of Set 6 | never
# Processing Record 46 of Set 6 | ossora
# Processing Record 47 of Set 6 | wladyslawowo
# Processing Record 48 of Set 6 | tambun
# Processing Record 49 of Set 6 | caruray
# Processing Record 50 of Set 6 | maarianhamina
# Processing Record 1 of Set 7 | juneau
# Processing Record 2 of Set 7 | plettenberg bay
# Processing Record 3 of Set 7 | hovd
# Processing Record 4 of Set 7 | tasiilaq
# Processing Record 5 of Set 7 | saint-pierre
# Processing Record 6 of Set 7 | urumqi
# Processing Record 7 of Set 7 | vigia
# Processing Record 8 of Set 7 | bambous virieux
# Processing Record 9 of Set 7 | cobija
# Processing Record 10 of Set 7 | north ogden
# Processing Record 11 of Set 7 | severo-kurilsk
# Processing Record 12 of Set 7 | guiren
# Processing Record 13 of Set 7 | great yarmouth
# Processing Record 14 of Set 7 | miri
# Processing Record 15 of Set 7 | egvekinot
# Processing Record 16 of Set 7 | takoradi
# Processing Record 17 of Set 7 | grand gaube
# Processing Record 18 of Set 7 | harqalah
# Processing Record 19 of Set 7 | worthington
# Processing Record 20 of Set 7 | ambon
# Processing Record 21 of Set 7 | kholodnyy
# Processing Record 22 of Set 7 | manhattan
# Processing Record 23 of Set 7 | cabedelo
# Processing Record 24 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 7 | ordu
# Processing Record 26 of Set 7 | paita
# Processing Record 27 of Set 7 | namibe
# Processing Record 28 of Set 7 | rosita
# Processing Record 29 of Set 7 | san cristobal
# Processing Record 30 of Set 7 | tabou
# Processing Record 31 of Set 7 | udayagiri
# Processing Record 32 of Set 7 | san quintin
# Processing Record 33 of Set 7 | longyan
# Processing Record 34 of Set 7 | campbeltown
# Processing Record 35 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 7 | victor harbor
# Processing Record 37 of Set 7 | svetlogorsk
# Processing Record 38 of Set 7 | bengkulu
# Processing Record 39 of Set 7 | sao joao da barra
# Processing Record 40 of Set 7 | phuket
# Processing Record 41 of Set 7 | kerteh
# City not found. Skipping...
# Processing Record 42 of Set 7 | hirara
# Processing Record 43 of Set 7 | grand-santi
# Processing Record 44 of Set 7 | los llanos de aridane
# Processing Record 45 of Set 7 | srednekolymsk
# Processing Record 46 of Set 7 | gaoua
# Processing Record 47 of Set 7 | carnarvon
# Processing Record 48 of Set 7 | puerto cabezas
# Processing Record 49 of Set 7 | hay river
# Processing Record 50 of Set 7 | mehamn
# Processing Record 1 of Set 8 | sovetskiy
# Processing Record 2 of Set 8 | puksoozero
# Processing Record 3 of Set 8 | tizimin
# Processing Record 4 of Set 8 | quelimane
# Processing Record 5 of Set 8 | poum
# Processing Record 6 of Set 8 | roma
# Processing Record 7 of Set 8 | talaya
# Processing Record 8 of Set 8 | argayash
# Processing Record 9 of Set 8 | gueugnon
# Processing Record 10 of Set 8 | pangody
# Processing Record 11 of Set 8 | ferrol
# Processing Record 12 of Set 8 | richards bay
# Processing Record 13 of Set 8 | hulan ergi
# Processing Record 14 of Set 8 | natal
# Processing Record 15 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 16 of Set 8 | muros
# Processing Record 17 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 8 | lompoc
# Processing Record 19 of Set 8 | barcelos
# Processing Record 20 of Set 8 | menongue
# Processing Record 21 of Set 8 | yar-sale
# Processing Record 22 of Set 8 | kununurra
# Processing Record 23 of Set 8 | guadix
# Processing Record 24 of Set 8 | alyangula
# Processing Record 25 of Set 8 | dongdu
# Processing Record 26 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 27 of Set 8 | ewo
# Processing Record 28 of Set 8 | tupik
# Processing Record 29 of Set 8 | palmer
# Processing Record 30 of Set 8 | algeciras
# Processing Record 31 of Set 8 | mozelos
# Processing Record 32 of Set 8 | khandyga
# Processing Record 33 of Set 8 | saldanha
# Processing Record 34 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 35 of Set 8 | coffs harbour
# Processing Record 36 of Set 8 | yinchuan
# Processing Record 37 of Set 8 | eureka
# Processing Record 38 of Set 8 | chunian
# Processing Record 39 of Set 8 | iranshahr
# Processing Record 40 of Set 8 | antsohihy
# Processing Record 41 of Set 8 | kloulklubed
# Processing Record 42 of Set 8 | laguna
# Processing Record 43 of Set 8 | shakhunya
# Processing Record 44 of Set 8 | akonolinga
# Processing Record 45 of Set 8 | asau
# Processing Record 46 of Set 8 | riyadh
# Processing Record 47 of Set 8 | kruisfontein
# Processing Record 48 of Set 8 | yellandu
# Processing Record 49 of Set 8 | sioux lookout
# Processing Record 50 of Set 8 | filingue
# Processing Record 1 of Set 9 | alicia
# Processing Record 2 of Set 9 | beringovskiy
# Processing Record 3 of Set 9 | paraiso
# Processing Record 4 of Set 9 | dikson
# Processing Record 5 of Set 9 | henties bay
# Processing Record 6 of Set 9 | feni
# Processing Record 7 of Set 9 | derzhavinsk
# Processing Record 8 of Set 9 | mount isa
# Processing Record 9 of Set 9 | waharoa
# Processing Record 10 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 11 of Set 9 | sobolevo
# Processing Record 12 of Set 9 | faya
# Processing Record 13 of Set 9 | tuatapere
# Processing Record 14 of Set 9 | port hedland
# Processing Record 15 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 16 of Set 9 | homer
# Processing Record 17 of Set 9 | de aar
# Processing Record 18 of Set 9 | banjarmasin
# Processing Record 19 of Set 9 | kemijarvi
# Processing Record 20 of Set 9 | praia da vitoria
# Processing Record 21 of Set 9 | tecoanapa
# Processing Record 22 of Set 9 | talnakh
# Processing Record 23 of Set 9 | marawi
# Processing Record 24 of Set 9 | hohhot
# Processing Record 25 of Set 9 | dakar
# Processing Record 26 of Set 9 | kangaatsiaq
# Processing Record 27 of Set 9 | mobile
# Processing Record 28 of Set 9 | acajutla
# Processing Record 29 of Set 9 | burica
# City not found. Skipping...
# Processing Record 30 of Set 9 | maniitsoq
# Processing Record 31 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 9 | touros
# Processing Record 33 of Set 9 | kapit
# Processing Record 34 of Set 9 | puerto escondido
# Processing Record 35 of Set 9 | fengzhen
# Processing Record 36 of Set 9 | fonte boa
# Processing Record 37 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 38 of Set 9 | tunduru
# City not found. Skipping...
# Processing Record 39 of Set 9 | lingyuan
# Processing Record 40 of Set 9 | morro bay
# Processing Record 41 of Set 9 | ati
# Processing Record 42 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 9 | serra talhada
# Processing Record 44 of Set 9 | tuy hoa
# Processing Record 45 of Set 9 | gol
# Processing Record 46 of Set 9 | antofagasta
# Processing Record 47 of Set 9 | zhigalovo
# Processing Record 48 of Set 9 | pimampiro
# Processing Record 49 of Set 9 | makakilo city
# Processing Record 50 of Set 9 | kiruna
# Processing Record 1 of Set 10 | bonfim
# Processing Record 2 of Set 10 | kismayo
# Processing Record 3 of Set 10 | valence
# Processing Record 4 of Set 10 | caravelas
# Processing Record 5 of Set 10 | muroto
# Processing Record 6 of Set 10 | campbell river
# Processing Record 7 of Set 10 | porosozero
# Processing Record 8 of Set 10 | kilmez
# City not found. Skipping...
# Processing Record 9 of Set 10 | bud
# Processing Record 10 of Set 10 | hailey
# Processing Record 11 of Set 10 | fairbanks
# Processing Record 12 of Set 10 | whitehorse
# Processing Record 13 of Set 10 | springbok
# Processing Record 14 of Set 10 | nur
# Processing Record 15 of Set 10 | colesberg
# Processing Record 16 of Set 10 | kalagarh
# Processing Record 17 of Set 10 | bowen
# Processing Record 18 of Set 10 | foca
# Processing Record 19 of Set 10 | lemesos
# City not found. Skipping...
# Processing Record 20 of Set 10 | harper
# Processing Record 21 of Set 10 | benguela
# Processing Record 22 of Set 10 | luunja
# Processing Record 23 of Set 10 | lastoursville
# Processing Record 24 of Set 10 | rosarito
# Processing Record 25 of Set 10 | obernai
# Processing Record 26 of Set 10 | barranca
# Processing Record 27 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 28 of Set 10 | peniche
# Processing Record 29 of Set 10 | suntar
# Processing Record 30 of Set 10 | boende
# Processing Record 31 of Set 10 | san matias
# Processing Record 32 of Set 10 | san patricio
# Processing Record 33 of Set 10 | griffith
# Processing Record 34 of Set 10 | sibolga
# Processing Record 35 of Set 10 | kailua
# Processing Record 36 of Set 10 | tianpeng
# Processing Record 37 of Set 10 | la palma
# Processing Record 38 of Set 10 | ballina
# Processing Record 39 of Set 10 | my tho
# Processing Record 40 of Set 10 | matay
# Processing Record 41 of Set 10 | moindou
# Processing Record 42 of Set 10 | simbahan
# Processing Record 43 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 10 | yumen
# Processing Record 45 of Set 10 | provideniya
# Processing Record 46 of Set 10 | bunia
# Processing Record 47 of Set 10 | la sarre
# Processing Record 48 of Set 10 | baykit
# Processing Record 49 of Set 10 | qandala
# Processing Record 50 of Set 10 | birao
# Processing Record 1 of Set 11 | phan thiet
# Processing Record 2 of Set 11 | ramanuj ganj
# Processing Record 3 of Set 11 | barra patuca
# Processing Record 4 of Set 11 | arroyo
# Processing Record 5 of Set 11 | buon me thuot
# City not found. Skipping...
# Processing Record 6 of Set 11 | poplar bluff
# Processing Record 7 of Set 11 | morehead
# Processing Record 8 of Set 11 | khasan
# Processing Record 9 of Set 11 | vostok
# Processing Record 10 of Set 11 | moussoro
# Processing Record 11 of Set 11 | billings
# Processing Record 12 of Set 11 | samarai
# Processing Record 13 of Set 11 | atambua
# Processing Record 14 of Set 11 | biltine
# Processing Record 15 of Set 11 | tineo
# Processing Record 16 of Set 11 | bandundu
# Processing Record 17 of Set 11 | oltina
# Processing Record 18 of Set 11 | glace bay
# Processing Record 19 of Set 11 | abu dhabi
# Processing Record 20 of Set 11 | bonavista
# Processing Record 21 of Set 11 | chornyanka
# Processing Record 22 of Set 11 | barcelona
# Processing Record 23 of Set 11 | thohoyandou
# Processing Record 24 of Set 11 | shitanjing
# Processing Record 25 of Set 11 | halifax
# Processing Record 26 of Set 11 | marsabit
# Processing Record 27 of Set 11 | annau
# Processing Record 28 of Set 11 | port moresby
# Processing Record 29 of Set 11 | indianola
# Processing Record 30 of Set 11 | ye
# City not found. Skipping...
# Processing Record 31 of Set 11 | saint-augustin
# Processing Record 32 of Set 11 | ouadda
# Processing Record 33 of Set 11 | fallon
# Processing Record 34 of Set 11 | raudeberg
# Processing Record 35 of Set 11 | buy
# Processing Record 36 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 11 | saint-joseph
# Processing Record 38 of Set 11 | hinton
# Processing Record 39 of Set 11 | iturama
# Processing Record 40 of Set 11 | visnes
# Processing Record 41 of Set 11 | presidente medici
# Processing Record 42 of Set 11 | dongsheng
# Processing Record 43 of Set 11 | kandri
# Processing Record 44 of Set 11 | lavrentiya
# Processing Record 45 of Set 11 | te anau
# Processing Record 46 of Set 11 | lata
# Processing Record 47 of Set 11 | ullapool
# Processing Record 48 of Set 11 | kilindoni
# Processing Record 49 of Set 11 | stroby egede
# Processing Record 50 of Set 11 | kirakira
# Processing Record 1 of Set 12 | truckee
# Processing Record 2 of Set 12 | chok chai
# Processing Record 3 of Set 12 | juba
# Processing Record 4 of Set 12 | mocajuba
# Processing Record 5 of Set 12 | puerto pinasco
# City not found. Skipping...
# Processing Record 6 of Set 12 | batagay
# Processing Record 7 of Set 12 | port lincoln
# Processing Record 8 of Set 12 | rochegda
# Processing Record 9 of Set 12 | yambio
# Processing Record 10 of Set 12 | shelburne
# Processing Record 11 of Set 12 | porto belo
# Processing Record 12 of Set 12 | high rock
# Processing Record 13 of Set 12 | bubaque
# Processing Record 14 of Set 12 | majene
# Processing Record 15 of Set 12 | san vicente
# Processing Record 16 of Set 12 | nyimba
# Processing Record 17 of Set 12 | teguise
# Processing Record 18 of Set 12 | umea
# Processing Record 19 of Set 12 | buala
# Processing Record 20 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 21 of Set 12 | tommot
# Processing Record 22 of Set 12 | polson
# Processing Record 23 of Set 12 | ust-shonosha
# Processing Record 24 of Set 12 | pacific grove
# Processing Record 25 of Set 12 | kindia
# Processing Record 26 of Set 12 | kon tum
# Processing Record 27 of Set 12 | tura
# Processing Record 28 of Set 12 | sangar
# Processing Record 29 of Set 12 | pedreiras
# Processing Record 30 of Set 12 | lexington
# Processing Record 31 of Set 12 | roald
# Processing Record 32 of Set 12 | west bay
# Processing Record 33 of Set 12 | tual
# Processing Record 34 of Set 12 | arsenyev
# Processing Record 35 of Set 12 | bukachacha
# Processing Record 36 of Set 12 | mahon
# Processing Record 37 of Set 12 | naze
# Processing Record 38 of Set 12 | saint-georges
# Processing Record 39 of Set 12 | aksarka
# Processing Record 40 of Set 12 | krasnystaw
# Processing Record 41 of Set 12 | srandakan
# Processing Record 42 of Set 12 | matai
# Processing Record 43 of Set 12 | ndele
# Processing Record 44 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 45 of Set 12 | calabozo
# Processing Record 46 of Set 12 | lotoshino
# Processing Record 47 of Set 12 | onega
# Processing Record 48 of Set 12 | adjumani
# Processing Record 49 of Set 12 | sabalgarh
# Processing Record 50 of Set 12 | chicama
# Processing Record 1 of Set 13 | tobermory
# Processing Record 2 of Set 13 | portland
# Processing Record 3 of Set 13 | eyl
# Processing Record 4 of Set 13 | piritiba
# Processing Record 5 of Set 13 | coihaique
# Processing Record 6 of Set 13 | sharlyk
# Processing Record 7 of Set 13 | big spring
# Processing Record 8 of Set 13 | labuhan
# Processing Record 9 of Set 13 | waitati
# Processing Record 10 of Set 13 | mathbaria
# Processing Record 11 of Set 13 | karaton
# Processing Record 12 of Set 13 | camapua
# Processing Record 13 of Set 13 | kodinsk
# Processing Record 14 of Set 13 | luwuk
# Processing Record 15 of Set 13 | aykhal
# Processing Record 16 of Set 13 | galesong
# Processing Record 17 of Set 13 | itarema
# Processing Record 18 of Set 13 | voh
# Processing Record 19 of Set 13 | nuuk
# Processing Record 20 of Set 13 | tari
# Processing Record 21 of Set 13 | ola
# Processing Record 22 of Set 13 | vaitape
# Processing Record 23 of Set 13 | ilfracombe
# Processing Record 24 of Set 13 | uray
# Processing Record 25 of Set 13 | invercargill
# Processing Record 26 of Set 13 | lagoa
# Processing Record 27 of Set 13 | berlevag
# Processing Record 28 of Set 13 | moose factory
# Processing Record 29 of Set 13 | florence
# Processing Record 30 of Set 13 | chumikan
# Processing Record 31 of Set 13 | alta floresta
# Processing Record 32 of Set 13 | carutapera
# Processing Record 33 of Set 13 | rio branco
# Processing Record 34 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 13 | bykovo
# Processing Record 36 of Set 13 | pacifica
# Processing Record 37 of Set 13 | temyasovo
# Processing Record 38 of Set 13 | bull savanna
# Processing Record 39 of Set 13 | neringa
# Processing Record 40 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 13 | dharchula
# Processing Record 42 of Set 13 | necochea
# Processing Record 43 of Set 13 | izumo
# Processing Record 44 of Set 13 | belaya gora
# Processing Record 45 of Set 13 | ugoofaaru
# Processing Record 46 of Set 13 | nassau
# Processing Record 47 of Set 13 | zyryanka
# Processing Record 48 of Set 13 | edea
# Processing Record 49 of Set 13 | tessalit
# Processing Record 50 of Set 13 | talas
# Processing Record 1 of Set 14 | hervey bay
# Processing Record 2 of Set 14 | gannan
# Processing Record 3 of Set 14 | shatsk
# Processing Record 4 of Set 14 | port said
# Processing Record 5 of Set 14 | stornoway
# Processing Record 6 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 14 | shar
# Processing Record 8 of Set 14 | sanpaul
# Processing Record 9 of Set 14 | sambava
# Processing Record 10 of Set 14 | bagotville
# Processing Record 11 of Set 14 | usakos
# Processing Record 12 of Set 14 | arica
# Processing Record 13 of Set 14 | kokopo
# Processing Record 14 of Set 14 | vieux-habitants
# Processing Record 15 of Set 14 | saedinenie
# Processing Record 16 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 17 of Set 14 | elat
# Processing Record 18 of Set 14 | olafsvik
# Processing Record 19 of Set 14 | isangel
# Processing Record 20 of Set 14 | nizhniy tsasuchey
# Processing Record 21 of Set 14 | caluquembe
# Processing Record 22 of Set 14 | jardim
# Processing Record 23 of Set 14 | nyurba
# Processing Record 24 of Set 14 | turukhansk
# Processing Record 25 of Set 14 | ozernovskiy
# Processing Record 26 of Set 14 | kristiinankaupunki
# Processing Record 27 of Set 14 | broken hill
# Processing Record 28 of Set 14 | dicabisagan
# Processing Record 29 of Set 14 | toguchin
# Processing Record 30 of Set 14 | loiza
# Processing Record 31 of Set 14 | maturin
# Processing Record 32 of Set 14 | tazovskiy
# Processing Record 33 of Set 14 | namatanai
# Processing Record 34 of Set 14 | boa vista
# Processing Record 35 of Set 14 | hambantota
# Processing Record 36 of Set 14 | kasane
# Processing Record 37 of Set 14 | meadow lake
# Processing Record 38 of Set 14 | shaoguan
# Processing Record 39 of Set 14 | zhigansk
# Processing Record 40 of Set 14 | mehran
# Processing Record 41 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 42 of Set 14 | izhma
# Processing Record 43 of Set 14 | havre-saint-pierre
# Processing Record 44 of Set 14 | aljezur
# Processing Record 45 of Set 14 | semirom
# Processing Record 46 of Set 14 | haslett
# Processing Record 47 of Set 14 | shanghai
# Processing Record 48 of Set 14 | san ramon de la nueva oran
# Processing Record 49 of Set 14 | zhoucheng
# Processing Record 50 of Set 14 | mocuba
# Processing Record 1 of Set 15 | daru
# Processing Record 2 of Set 15 | jinka
# Processing Record 3 of Set 15 | joao pinheiro
# Processing Record 4 of Set 15 | hudiksvall
# Processing Record 5 of Set 15 | channel-port aux basques
# Processing Record 6 of Set 15 | flekkefjord
# Processing Record 7 of Set 15 | porto seguro
# Processing Record 8 of Set 15 | meulaboh
# Processing Record 9 of Set 15 | cartagena
# Processing Record 10 of Set 15 | mareeba
# Processing Record 11 of Set 15 | charagua
# Processing Record 12 of Set 15 | erzin
# Processing Record 13 of Set 15 | gagra
# Processing Record 14 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 15 | tokonou
# Processing Record 16 of Set 15 | batagay-alyta
# Processing Record 17 of Set 15 | maldonado
# Processing Record 18 of Set 15 | neuquen
# Processing Record 19 of Set 15 | umba
# Processing Record 20 of Set 15 | saurimo
# Processing Record 21 of Set 15 | tres passos
# Processing Record 22 of Set 15 | novoagansk
# Processing Record 23 of Set 15 | westport
# Processing Record 24 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 25 of Set 15 | honningsvag
# Processing Record 26 of Set 15 | vaxjo
# Processing Record 27 of Set 15 | jumla
# Processing Record 28 of Set 15 | sola
# Processing Record 29 of Set 15 | chapais
# Processing Record 30 of Set 15 | la asuncion
# Processing Record 31 of Set 15 | bilma
# Processing Record 32 of Set 15 | honjo
# Processing Record 33 of Set 15 | manokwari
# Processing Record 34 of Set 15 | komsomolskiy
# Processing Record 35 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 15 | muriae
# Processing Record 37 of Set 15 | kysyl-syr
# Processing Record 38 of Set 15 | tateyama
# Processing Record 39 of Set 15 | ostrowiec swietokrzyski
# Processing Record 40 of Set 15 | waingapu
# Processing Record 41 of Set 15 | vanimo
# Processing Record 42 of Set 15 | we
# City not found. Skipping...
# Processing Record 43 of Set 15 | merauke
# Processing Record 44 of Set 15 | prainha
# Processing Record 45 of Set 15 | oistins
# Processing Record 46 of Set 15 | keflavik
# Processing Record 47 of Set 15 | sarmanovo
# Processing Record 48 of Set 15 | tutla
# City not found. Skipping...
# Processing Record 49 of Set 15 | mazamari
# Processing Record 50 of Set 15 | fuyang
# Processing Record 1 of Set 16 | anaconda
# Processing Record 2 of Set 16 | xalpatlahuac
# Processing Record 3 of Set 16 | kenai
# Processing Record 4 of Set 16 | road town
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 699

# %%
#Save the new DataFrame as a CSV file
challenge_data_df = pd.DataFrame(city_data)
challenge_data_df.to_csv(path_or_buf='C:/Users/davec/Desktop/Class/6. WeatherPy with Python APIs\Challenge\Challenge_Results/WeatherPy_challenge.csv', index_label='City_ID')
